# %% [markdown]
# # Mathematical operators and order of operations

# %%
8+7
# Out:
# 15

# %%
6*8
# Out:
# 48

# %%
24/15
# Out:
# 1.6

# %%
3**3
# Out:
# 27

# %%
24%15
# Out:
# 9

# %%
7+7*3
# Out:
# 28

# %%
(7+7)*3
# Out:
# 42

# %%
import math

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.log(3)
# Out:
# 1.0986122886681098

# %%
math.log(100,10)
# Out:
# 2.0

# %% [markdown]
# # Writing a program to calculate factors of an integer

# %%
def calculate_factors(number):
    list_of_factors = []
    for i in range(1,number+1):
        if number % i ==0:
            list_of_factors.append(i)
    return list_of_factors

# %%
calculate_factors(30)
# Out:
# [1, 2, 3, 5, 6, 10, 15, 30]

# %% [markdown]
# # Challenge: Converting units of measurement

# %%
def select_conversion():
    print("Select conversion type:")
    print("1.Kilometers to Miles")
    print("2.Miles to Kilometers")
    print("0.Exit")
    
def kilometers_to_miles():
    km=float(input("Enter the distance in kilometers: "))
    miles=km*0.621371
    print(f"{km} kilometers is equal to {miles} miles")
    
def miles_to_kilometers():
    miles=float(input("Enter the distance in miles: "))
    km=miles/0.621371
    print(f"{miles} miles is equal to {km} kilometers")

select_conversion()
option=input("Enter option (1/2/0): ")
if option=='1':
    kilometers_to_miles()
elif option=='2':
    miles_to_kilometers()
elif option=='0':
    print("Exiting the program.")
else:
    print("Invalid option. Please select a valid option.")
# Out:
# Select conversion type:
# 1.Kilometers to Miles
# 2.Miles to Kilometers
# 0.Exit
# Exiting the program.

# %% [markdown]
# # Vector arithmetic

# %%
import numpy as np

# %%
a=np.array([6,7,8])
b=np.array([5,-4,3])
c=np.array([5,-4,3,2])

# %%
a+b
# Out:
# array([11,  3, 11])

# %%
a+c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a+c
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
a-b
# Out:
# array([ 1, 11,  5])

# %%
a-c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a-c
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
a*b
# Out:
# array([ 30, -28,  24])

# %%
a*5
# Out:
# array([30, 35, 40])

# %% [markdown]
# # Cartesian coordinate system

# %%
import matplotlib.pyplot as plt
import random as r

# %%
x=5
y=7
plt.plot(x,y,"ro")
plt.show()

# %%
for i in range(0,5):
    x=r.randint(-3,3)
    y=r.randint(-3,3)
    plt.plot(x,y,"ro")
plt.axis("square")
plt.grid()
plt.show()

# %%
ax=plt.axes()
ax.arrow(2,1,5,6,head_width=0.2,head_length=0.2)
plt.xlim(0,10)
plt.ylim(0,10)
plt.show()

# %% [markdown]
# # Dot product of vectors

# %%
a=np.array([10,15,20,25])
b=np.array([5,4,3,2])
print(np.dot(a,b))
# Out:
# 220

# %% [markdown]
# # Scalar and vector projection

# %%
projection_of_a_on_b = (np.dot (a,b)/
np.sqrt(b.dot (b))) *b

# %% [markdown]
# # Basis, linear independence, and span

# %% [markdown]
# # Transposing matrices

# %%
import numpy as np
def transpose(a):
    matrix=[]
    m=len(a)
    n=len(a[0])
    for i in range(n):
        matrix.append([])
        for j in range(m):
            matrix[i].append(a[j][i])
    return matrix

# %%
a=[[1,5,6],[4,8,3]]
transpose(a)
# Out:
# [[1, 4], [5, 8], [6, 3]]

# %%
np.array(a).transpose()
# Out:
# array([[1, 4],
#        [5, 8],
#        [6, 3]])

# %% [markdown]
# # Creating 3D shapes

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
axes=[10,10,10]
data=np.ones(axes)
cube=plt.figure()
ax=cube.add_subplot(projection='3d')
ax.voxels(data,facecolor="green",alpha=0.25)
plt.show()
